# %% [markdown]
# # This case study a

# %%
#using Pkg
#Pkg.add("Plots")
using Plots

s1 = sin.((1:1000)./20)
plot(s1, linewidth=2, title = "S1")

# %%
s2 = vec(repeat(((1:200).-100)/100, 5))
plot(s2,linewidth=2,title="S2")

# %%
#mixing matrix
A = [0.291 -0.5439 ; 0.6557 0.5572]
S = hcat(s1,s2)
X = S * A
# Out:
# 1000×2 Array{Float64,2}:
#  -0.634599  -0.578812
#  -0.613534  -0.600355
#  -0.592543  -0.621763
#  -0.571659  -0.642968
#  -0.55092   -0.663903
#  -0.530362  -0.684501
#  -0.510018  -0.704698
#  -0.489923  -0.724429
#  -0.470112  -0.74363
#  -0.450617  -0.76224
#  -0.431471  -0.780198
#  -0.412705  -0.797445
#  -0.39435   -0.813925
#   ⋮
#   0.371709   0.891898
#   0.3885     0.87834
#   0.405796   0.86384
#   0.423569   0.848449
#   0.441791   0.832218
#   0.460433   0.815202
#   0.479465   0.797458
#   0.498855   0.779044
#   0.518572   0.760019
#   0.538583   0.740446
#   0.558853   0.720387
#   0.579349   0.699906

# %%
plot(X[:,1], linewidth=2, title = "X1")

# %%
plot(X[:,2], linewidth=2, title = "X2")

# %%
include("fastICA.jl")
W = fastICA.fast_ica(200,2,Array(X),0.0001,1.,true)
# Out:
# wp = [0.711886, 0.288114]
# w1 = [-0.926961, -0.375159]
# W for iter 1 = [0.711886 0.288114; 0.808672 0.425994]
# Change for iter 1 = 0.2320213379846403
# wp = [-0.926961, -0.375159]
# w1 = [0.926961, 0.375159]
# W for iter 2 = [0.711886 0.288114; 0.808672 0.425994]
# Change for iter 2 = 2.6423307986078726e-14
# wp = [-0.552041, -0.143473]
# w1 = [-0.825833, -0.563915]
# W for iter 1 = [0.711886 0.288114; 0.654972 0.345028]
# Change for iter 1 = 0.46319947720870513
# wp = [-0.825833, -0.563915]
# w1 = [-0.991009, -0.133799]
# W for iter 2 = [0.711886 0.288114; 0.654972 0.345028]
# Change for iter 2 = 0.1061418077551256
# wp = [-0.991009, -0.133799]
# w1 = [-0.661499, -0.749946]
# W for iter 3 = [0.711886 0.288114; 0.654972 0.345028]
# Change for iter 3 = 0.244107003720471
# wp = [-0.661499, -0.749946]
# w1 = [-0.998322, 0.0579118]
# W for iter 4 = [0.711886 0.288114; 0.654972 0.345028]
# Change for iter 4 = 0.38304180823871026
# wp = [-0.998322, 0.0579118]
# w1 = [-0.255599, -0.966783]
# W for iter 5 = [0.711886 0.288114; 0.654972 0.345028]
# Change for iter 5 = 0.8008180131654726
# wp = [-0.255599, -0.966783]
# w1 = [-0.957024, 0.290008]
# W for iter 6 = [0.711886 0.288114; 0.654972 0.345028]
# Change for iter 6 = 0.9642393524308241
# wp = [-0.957024, 0.290008]
# w1 = [0.239516, -0.970893]
# W for iter 7 = [0.711886 0.288114; 0.654972 0.345028]
# Change for iter 7 = 0.48921079683254065
# wp = [0.239516, -0.970893]
# w1 = [-0.877418, 0.479726]
# W for iter 8 = [0.711886 0.288114; 0.654972 0.345028]
# Change for iter 8 = 0.32408183972983384
# wp = [-0.877418, 0.479726]
# w1 = [0.507901, -0.861415]
# W for iter 9 = [0.711886 0.288114; 0.654972 0.345028]
# Change for iter 9 = 0.14111454050846062
# wp = [0.507901, -0.861415]
# w1 = [-0.805026, 0.59324]
# W for iter 10 = [0.711886 0.288114; 0.654972 0.345028]
# Change for iter 10 = 0.08010068849682161
# wp = [-0.805026, 0.59324]
# w1 = [0.619208, -0.785227]
# W for iter 11 = [0.711886 0.288114; 0.654972 0.345028]
# Change for iter 11 = 0.03569371908344343
# wp = [0.619208, -0.785227]
# w1 = [-0.758517, 0.651654]
# W for iter 12 = [0.711886 0.288114; 0.654972 0.345028]
# Change for iter 12 = 0.018624371133381334
# wp = [-0.758517, 0.651654]
# w1 = [0.666656, -0.745365]
# W for iter 13 = [0.711886 0.288114; 0.654972 0.345028]
# Change for iter 13 = 0.008610096589759308
# wp = [0.666656, -0.745365]
# w1 = [-0.732956, 0.680276]
# W for iter 14 = [0.711886 0.288114; 0.654972 0.345028]
# Change for iter 14 = 0.0043160980834819895
# wp = [-0.732956, 0.680276]
# w1 = [0.688025, -0.725687]
# W for iter 15 = [0.711886 0.288114; 0.654972 0.345028]
# Change for iter 15 = 0.0020404279347376875
# wp = [0.688025, -0.725687]
# w1 = [-0.719843, 0.694137]
# W for iter 16 = [0.711886 0.288114; 0.654972 0.345028]
# Change for iter 16 = 0.0010038803539995644
# wp = [-0.719843, 0.694137]
# w1 = [0.69799, -0.716108]
# W for iter 17 = [0.711886 0.288114; 0.654972 0.345028]
# Change for iter 17 = 0.00048014390346495794
# wp = [0.69799, -0.716108]
# w1 = [-0.713322, 0.700836]
# W for iter 18 = [0.711886 0.288114; 0.654972 0.345028]
# Change for iter 18 = 0.0002341548881922284
# wp = [-0.713322, 0.700836]
# w1 = [0.702723, -0.711464]
# W for iter 19 = [0.711886 0.288114; 0.654972 0.345028]
# Change for iter 19 = 0.0001126456095212891
# wp = [0.702723, -0.711464]
# w1 = [-0.710126, 0.704074]
# W for iter 20 = [0.711886 0.288114; 0.654972 0.345028]
# Change for iter 20 = 5.470424620801495e-5
# K=[0.0368663 0.0770381; 0.0994869 -0.0476091]
# 2×1000 Array{Float64,2}:
#  -0.0767463  -0.0763939  -0.0760395  …   0.0777793   0.0781544   0.078523
#   0.0232967   0.0261215   0.0289311     -0.0416344  -0.0389754  -0.0362693

# %%
plot(W[1,:,],linewidth=2, title = "S'1")

# %%
plot(W[2,:,],linewidth=2, title = "S'2")
