# %% [markdown]
# # Case study with mixed images using the FICA implementation

# %%
#using Pkg
#Pkg.add("ImageView")
using Images, FileIO, Colors

# %% [markdown]
# ## Loading the test images and converting them to a grayscale image
# For this case study we used 2 cat pictures, they will be refered to as cat one and cat two by
# order of appearance

# %%
cat_one = load("cat_one_resize.jpg")
cat_oneg = Gray.(cat_one)
# Out:
# 334×500 Array{Gray{N0f8},2} with eltype Gray{Normed{UInt8,8}}:
#  Gray{N0f8}(0.78)   Gray{N0f8}(0.78)   …  Gray{N0f8}(0.776)
#  Gray{N0f8}(0.784)  Gray{N0f8}(0.784)     Gray{N0f8}(0.776)
#  Gray{N0f8}(0.784)  Gray{N0f8}(0.784)     Gray{N0f8}(0.776)
#  Gray{N0f8}(0.784)  Gray{N0f8}(0.788)     Gray{N0f8}(0.78)
#  Gray{N0f8}(0.788)  Gray{N0f8}(0.788)     Gray{N0f8}(0.776)
#  Gray{N0f8}(0.788)  Gray{N0f8}(0.788)  …  Gray{N0f8}(0.773)
#  Gray{N0f8}(0.792)  Gray{N0f8}(0.792)     Gray{N0f8}(0.773)
#  Gray{N0f8}(0.792)  Gray{N0f8}(0.792)     Gray{N0f8}(0.769)
#  Gray{N0f8}(0.788)  Gray{N0f8}(0.788)     Gray{N0f8}(0.765)
#  Gray{N0f8}(0.788)  Gray{N0f8}(0.788)     Gray{N0f8}(0.765)
#  Gray{N0f8}(0.788)  Gray{N0f8}(0.788)  …  Gray{N0f8}(0.765)
#  Gray{N0f8}(0.784)  Gray{N0f8}(0.784)     Gray{N0f8}(0.757)
#  Gray{N0f8}(0.784)  Gray{N0f8}(0.784)     Gray{N0f8}(0.753)
#  ⋮                                     ⋱
#  Gray{N0f8}(0.82)   Gray{N0f8}(0.824)     Gray{N0f8}(0.69)
#  Gray{N0f8}(0.812)  Gray{N0f8}(0.82)      Gray{N0f8}(0.702)
#  Gray{N0f8}(0.808)  Gray{N0f8}(0.82)      Gray{N0f8}(0.698)
#  Gray{N0f8}(0.808)  Gray{N0f8}(0.82)   …  Gray{N0f8}(0.686)
#  Gray{N0f8}(0.804)  Gray{N0f8}(0.808)     Gray{N0f8}(0.702)
#  Gray{N0f8}(0.816)  Gray{N0f8}(0.8)       Gray{N0f8}(0.643)
#  Gray{N0f8}(0.796)  Gray{N0f8}(0.82)      Gray{N0f8}(0.627)
#  Gray{N0f8}(0.808)  Gray{N0f8}(0.804)     Gray{N0f8}(0.698)
#  Gray{N0f8}(0.82)   Gray{N0f8}(0.808)  …  Gray{N0f8}(0.714)
#  Gray{N0f8}(0.812)  Gray{N0f8}(0.816)     Gray{N0f8}(0.725)
#  Gray{N0f8}(0.804)  Gray{N0f8}(0.808)     Gray{N0f8}(0.706)
#  Gray{N0f8}(0.796)  Gray{N0f8}(0.804)     Gray{N0f8}(0.682)

# %%
cat_two = load("cat_two_resize.jpg")
cat_twog = Gray.(cat_two)
# Out:
# 334×500 Array{Gray{N0f8},2} with eltype Gray{Normed{UInt8,8}}:
#  Gray{N0f8}(1.0)    Gray{N0f8}(1.0)    …  Gray{N0f8}(0.529)
#  Gray{N0f8}(1.0)    Gray{N0f8}(1.0)       Gray{N0f8}(0.525)
#  Gray{N0f8}(1.0)    Gray{N0f8}(1.0)       Gray{N0f8}(0.51)
#  Gray{N0f8}(1.0)    Gray{N0f8}(1.0)       Gray{N0f8}(0.502)
#  Gray{N0f8}(1.0)    Gray{N0f8}(1.0)       Gray{N0f8}(0.498)
#  Gray{N0f8}(1.0)    Gray{N0f8}(1.0)    …  Gray{N0f8}(0.498)
#  Gray{N0f8}(1.0)    Gray{N0f8}(1.0)       Gray{N0f8}(0.49)
#  Gray{N0f8}(1.0)    Gray{N0f8}(1.0)       Gray{N0f8}(0.494)
#  Gray{N0f8}(1.0)    Gray{N0f8}(1.0)       Gray{N0f8}(0.49)
#  Gray{N0f8}(1.0)    Gray{N0f8}(1.0)       Gray{N0f8}(0.486)
#  Gray{N0f8}(1.0)    Gray{N0f8}(1.0)    …  Gray{N0f8}(0.482)
#  Gray{N0f8}(1.0)    Gray{N0f8}(1.0)       Gray{N0f8}(0.486)
#  Gray{N0f8}(1.0)    Gray{N0f8}(1.0)       Gray{N0f8}(0.486)
#  ⋮                                     ⋱
#  Gray{N0f8}(0.875)  Gray{N0f8}(0.886)     Gray{N0f8}(0.957)
#  Gray{N0f8}(0.89)   Gray{N0f8}(0.898)     Gray{N0f8}(0.957)
#  Gray{N0f8}(0.906)  Gray{N0f8}(0.914)     Gray{N0f8}(0.957)
#  Gray{N0f8}(0.922)  Gray{N0f8}(0.925)  …  Gray{N0f8}(0.957)
#  Gray{N0f8}(0.929)  Gray{N0f8}(0.933)     Gray{N0f8}(0.957)
#  Gray{N0f8}(0.937)  Gray{N0f8}(0.941)     Gray{N0f8}(0.957)
#  Gray{N0f8}(0.945)  Gray{N0f8}(0.945)     Gray{N0f8}(0.957)
#  Gray{N0f8}(0.953)  Gray{N0f8}(0.957)     Gray{N0f8}(0.957)
#  Gray{N0f8}(0.957)  Gray{N0f8}(0.957)  …  Gray{N0f8}(0.957)
#  Gray{N0f8}(0.957)  Gray{N0f8}(0.957)     Gray{N0f8}(0.953)
#  Gray{N0f8}(0.957)  Gray{N0f8}(0.957)     Gray{N0f8}(0.957)
#  Gray{N0f8}(0.957)  Gray{N0f8}(0.957)     Gray{N0f8}(0.953)

# %% [markdown]
# ## Mixing the images together to create 2 mixed images
# For each image we use a different factor ( array A )
# the first mixed image has a stronger presence from cat two and the second image a stronger presence from cat one

# %%
using LinearAlgebra
#convert image to array
mat_one = convert(Array{Float64},cat_oneg);
mat_two = convert(Array{Float64},cat_twog);
#get rows and column to later reconstruct the mixed image
rows,col = size(mat_one)
#convert 2D images to 1D (vector)
vec_one = vec(mat_one)';
vec_two = vec(mat_two)';

S = vcat(vec_one , vec_two)';

#generate first mixed signal
#factor used for the image
#A = [0.2 , 0.8] 
A = [0.6 , 0.4] 

X = (S .* A')'

X = X[1,:,]+X[2,:,]

imageX = reshape(X,rows,col)
img = colorview(Gray, imageX)
# Out:
# 334×500 reinterpret(Gray{Float64}, ::Array{Float64,2}):
#  Gray{Float64}(0.868235)  Gray{Float64}(0.868235)  …  Gray{Float64}(0.677647)
#  Gray{Float64}(0.870588)  Gray{Float64}(0.870588)     Gray{Float64}(0.676078)
#  Gray{Float64}(0.870588)  Gray{Float64}(0.870588)     Gray{Float64}(0.669804)
#  Gray{Float64}(0.870588)  Gray{Float64}(0.872941)     Gray{Float64}(0.66902)
#  Gray{Float64}(0.872941)  Gray{Float64}(0.872941)     Gray{Float64}(0.665098)
#  Gray{Float64}(0.872941)  Gray{Float64}(0.872941)  …  Gray{Float64}(0.662745)
#  Gray{Float64}(0.875294)  Gray{Float64}(0.875294)     Gray{Float64}(0.659608)
#  Gray{Float64}(0.875294)  Gray{Float64}(0.875294)     Gray{Float64}(0.658824)
#  Gray{Float64}(0.872941)  Gray{Float64}(0.872941)     Gray{Float64}(0.654902)
#  Gray{Float64}(0.872941)  Gray{Float64}(0.872941)     Gray{Float64}(0.653333)
#  Gray{Float64}(0.872941)  Gray{Float64}(0.872941)  …  Gray{Float64}(0.651765)
#  Gray{Float64}(0.870588)  Gray{Float64}(0.870588)     Gray{Float64}(0.648627)
#  Gray{Float64}(0.870588)  Gray{Float64}(0.870588)     Gray{Float64}(0.646275)
#  ⋮                                                 ⋱
#  Gray{Float64}(0.841569)  Gray{Float64}(0.848627)     Gray{Float64}(0.796863)
#  Gray{Float64}(0.843137)  Gray{Float64}(0.85098)      Gray{Float64}(0.803922)
#  Gray{Float64}(0.847059)  Gray{Float64}(0.857255)     Gray{Float64}(0.801569)
#  Gray{Float64}(0.853333)  Gray{Float64}(0.861961)  …  Gray{Float64}(0.79451)
#  Gray{Float64}(0.854118)  Gray{Float64}(0.858039)     Gray{Float64}(0.803922)
#  Gray{Float64}(0.864314)  Gray{Float64}(0.856471)     Gray{Float64}(0.768627)
#  Gray{Float64}(0.855686)  Gray{Float64}(0.869804)     Gray{Float64}(0.759216)
#  Gray{Float64}(0.865882)  Gray{Float64}(0.865098)     Gray{Float64}(0.801569)
#  Gray{Float64}(0.87451)   Gray{Float64}(0.867451)  …  Gray{Float64}(0.81098)
#  Gray{Float64}(0.869804)  Gray{Float64}(0.872157)     Gray{Float64}(0.816471)
#  Gray{Float64}(0.865098)  Gray{Float64}(0.867451)     Gray{Float64}(0.806275)
#  Gray{Float64}(0.860392)  Gray{Float64}(0.865098)     Gray{Float64}(0.790588)

# %%
#generate second mixed signal
#factor used for the image
#A = [0.8 , 0.2] 
A = [0.4 , 0.6] 
Z = (S .* A')'

Z = Z[1,:,]+Z[2,:,]
mixed_signal = hcat(X,Z);
imageZ = reshape(Z,rows,col)
img = colorview(Gray,imageZ)
# Out:
# 334×500 reinterpret(Gray{Float64}, ::Array{Float64,2}):
#  Gray{Float64}(0.912157)  Gray{Float64}(0.912157)  …  Gray{Float64}(0.628235)
#  Gray{Float64}(0.913725)  Gray{Float64}(0.913725)     Gray{Float64}(0.625882)
#  Gray{Float64}(0.913725)  Gray{Float64}(0.913725)     Gray{Float64}(0.616471)
#  Gray{Float64}(0.913725)  Gray{Float64}(0.915294)     Gray{Float64}(0.613333)
#  Gray{Float64}(0.915294)  Gray{Float64}(0.915294)     Gray{Float64}(0.609412)
#  Gray{Float64}(0.915294)  Gray{Float64}(0.915294)  …  Gray{Float64}(0.607843)
#  Gray{Float64}(0.916863)  Gray{Float64}(0.916863)     Gray{Float64}(0.603137)
#  Gray{Float64}(0.916863)  Gray{Float64}(0.916863)     Gray{Float64}(0.603922)
#  Gray{Float64}(0.915294)  Gray{Float64}(0.915294)     Gray{Float64}(0.6)
#  Gray{Float64}(0.915294)  Gray{Float64}(0.915294)     Gray{Float64}(0.597647)
#  Gray{Float64}(0.915294)  Gray{Float64}(0.915294)  …  Gray{Float64}(0.595294)
#  Gray{Float64}(0.913725)  Gray{Float64}(0.913725)     Gray{Float64}(0.59451)
#  Gray{Float64}(0.913725)  Gray{Float64}(0.913725)     Gray{Float64}(0.592941)
#  ⋮                                                 ⋱
#  Gray{Float64}(0.852549)  Gray{Float64}(0.861176)     Gray{Float64}(0.850196)
#  Gray{Float64}(0.858824)  Gray{Float64}(0.866667)     Gray{Float64}(0.854902)
#  Gray{Float64}(0.866667)  Gray{Float64}(0.876078)     Gray{Float64}(0.853333)
#  Gray{Float64}(0.876078)  Gray{Float64}(0.883137)  …  Gray{Float64}(0.848627)
#  Gray{Float64}(0.879216)  Gray{Float64}(0.883137)     Gray{Float64}(0.854902)
#  Gray{Float64}(0.888627)  Gray{Float64}(0.884706)     Gray{Float64}(0.831373)
#  Gray{Float64}(0.88549)   Gray{Float64}(0.894902)     Gray{Float64}(0.825098)
#  Gray{Float64}(0.894902)  Gray{Float64}(0.895686)     Gray{Float64}(0.853333)
#  Gray{Float64}(0.901961)  Gray{Float64}(0.897255)  …  Gray{Float64}(0.859608)
#  Gray{Float64}(0.898824)  Gray{Float64}(0.900392)     Gray{Float64}(0.861961)
#  Gray{Float64}(0.895686)  Gray{Float64}(0.897255)     Gray{Float64}(0.856471)
#  Gray{Float64}(0.892549)  Gray{Float64}(0.895686)     Gray{Float64}(0.844706)

# %% [markdown]
# ## Applying the FICA algorithm

# %%
include("fastICA.jl")

#forced weights
wei = [0.86456941 1.0646533 ; 0.07053282 0.8470662]

W = fastICA.whiten(mixed_signal)
X1 = mixed_signal * W'
#direct call to deflation function to pass weights
#a = fastICA.fast_ica_def(200,2,Array(X1'),0.0001,wei, 1.)
#a = fastICA.fast_ica(200,2,Array(X1'),0.0001, 1.)
K = a * W
S = K * mixed_signal';
# Out:
# WARNING: replacing module fastICA.

# %% [markdown]
# ## Results

# %%
firstres = reshape(S[1,:,]+S[2,:,],rows,col)
scale = scaleminmax(round(Int8,minimum(firstres)),round(Int8,maximum(firstres)))
img = colorview(Gray, scale.(firstres))
# Out:
# 334×500 reinterpret(Gray{Float64}, ::Array{Float64,2}):
#  Gray{Float64}(0.910254)  Gray{Float64}(0.910254)  …  Gray{Float64}(0.928488)
#  Gray{Float64}(0.915074)  Gray{Float64}(0.915074)     Gray{Float64}(0.92868)
#  Gray{Float64}(0.915074)  Gray{Float64}(0.915074)     Gray{Float64}(0.929448)
#  Gray{Float64}(0.915074)  Gray{Float64}(0.919894)     Gray{Float64}(0.934653)
#  Gray{Float64}(0.919894)  Gray{Float64}(0.919894)     Gray{Float64}(0.930025)
#  Gray{Float64}(0.919894)  Gray{Float64}(0.919894)  …  Gray{Float64}(0.925204)
#  Gray{Float64}(0.924714)  Gray{Float64}(0.924714)     Gray{Float64}(0.925588)
#  Gray{Float64}(0.924714)  Gray{Float64}(0.924714)     Gray{Float64}(0.920576)
#  Gray{Float64}(0.919894)  Gray{Float64}(0.919894)     Gray{Float64}(0.915948)
#  Gray{Float64}(0.919894)  Gray{Float64}(0.919894)     Gray{Float64}(0.91614)
#  Gray{Float64}(0.919894)  Gray{Float64}(0.919894)  …  Gray{Float64}(0.916332)
#  Gray{Float64}(0.915074)  Gray{Float64}(0.915074)     Gray{Float64}(0.906499)
#  Gray{Float64}(0.915074)  Gray{Float64}(0.915074)     Gray{Float64}(0.901679)
#  ⋮                                                 ⋱
#  Gray{Float64}(0.964605)  Gray{Float64}(0.968849)     Gray{Float64}(0.801499)
#  Gray{Float64}(0.954195)  Gray{Float64}(0.963452)     Gray{Float64}(0.81596)
#  Gray{Float64}(0.948607)  Gray{Float64}(0.962683)     Gray{Float64}(0.81114)
#  Gray{Float64}(0.947838)  Gray{Float64}(0.962107)  …  Gray{Float64}(0.796679)
#  Gray{Float64}(0.942634)  Gray{Float64}(0.947262)     Gray{Float64}(0.81596)
#  Gray{Float64}(0.95671)   Gray{Float64}(0.937237)     Gray{Float64}(0.743656)
#  Gray{Float64}(0.932224)  Gray{Float64}(0.961146)     Gray{Float64}(0.724374)
#  Gray{Float64}(0.946301)  Gray{Float64}(0.941289)     Gray{Float64}(0.81114)
#  Gray{Float64}(0.96057)   Gray{Float64}(0.946109)  …  Gray{Float64}(0.830421)
#  Gray{Float64}(0.950929)  Gray{Float64}(0.95575)      Gray{Float64}(0.845074)
#  Gray{Float64}(0.941289)  Gray{Float64}(0.946109)     Gray{Float64}(0.820781)
#  Gray{Float64}(0.931648)  Gray{Float64}(0.941289)     Gray{Float64}(0.792051)

# %%
secondres = reshape(S[1,:,]-S[2,:,],rows,col)
scale = scaleminmax(round(Int8,minimum(secondres)),round(Int8,maximum(secondres)))
img = colorview(Gray, scale.(secondres))
# Out:
# 334×500 reinterpret(Gray{Float64}, ::Array{Float64,2}):
#  Gray{Float64}(0.721539)  Gray{Float64}(0.721539)  …  Gray{Float64}(0.38615)
#  Gray{Float64}(0.720314)  Gray{Float64}(0.720314)     Gray{Float64}(0.383345)
#  Gray{Float64}(0.720314)  Gray{Float64}(0.720314)     Gray{Float64}(0.372124)
#  Gray{Float64}(0.720314)  Gray{Float64}(0.719089)     Gray{Float64}(0.365289)
#  Gray{Float64}(0.719089)  Gray{Float64}(0.719089)     Gray{Float64}(0.363709)
#  Gray{Float64}(0.719089)  Gray{Float64}(0.719089)  …  Gray{Float64}(0.364934)
#  Gray{Float64}(0.717864)  Gray{Float64}(0.717864)     Gray{Float64}(0.359324)
#  Gray{Float64}(0.717864)  Gray{Float64}(0.717864)     Gray{Float64}(0.363354)
#  Gray{Float64}(0.719089)  Gray{Float64}(0.719089)     Gray{Float64}(0.361774)
#  Gray{Float64}(0.719089)  Gray{Float64}(0.719089)     Gray{Float64}(0.358968)
#  Gray{Float64}(0.719089)  Gray{Float64}(0.719089)  …  Gray{Float64}(0.356163)
#  Gray{Float64}(0.720314)  Gray{Float64}(0.720314)     Gray{Float64}(0.361418)
#  Gray{Float64}(0.720314)  Gray{Float64}(0.720314)     Gray{Float64}(0.362643)
#  ⋮                                                 ⋱
#  Gray{Float64}(0.619526)  Gray{Float64}(0.626716)     Gray{Float64}(0.718857)
#  Gray{Float64}(0.633196)  Gray{Float64}(0.636357)     Gray{Float64}(0.715182)
#  Gray{Float64}(0.645642)  Gray{Float64}(0.647577)     Gray{Float64}(0.716407)
#  Gray{Float64}(0.656862)  Gray{Float64}(0.655992)  …  Gray{Float64}(0.720082)
#  Gray{Float64}(0.663697)  Gray{Float64}(0.665278)     Gray{Float64}(0.715182)
#  Gray{Float64}(0.665633)  Gray{Float64}(0.673338)     Gray{Float64}(0.733556)
#  Gray{Float64}(0.677368)  Gray{Float64}(0.670018)     Gray{Float64}(0.738456)
#  Gray{Float64}(0.679303)  Gray{Float64}(0.683333)     Gray{Float64}(0.716407)
#  Gray{Float64}(0.678433)  Gray{Float64}(0.682108)  …  Gray{Float64}(0.711507)
#  Gray{Float64}(0.680883)  Gray{Float64}(0.679658)     Gray{Float64}(0.705027)
#  Gray{Float64}(0.683333)  Gray{Float64}(0.682108)     Gray{Float64}(0.713957)
#  Gray{Float64}(0.685783)  Gray{Float64}(0.683333)     Gray{Float64}(0.718502)

# %%
function mserror(A,B,width,height) sum = 0.0
    for x = 1:width
       for y = 1:height
          difference = (A[x,y] - B[x,y])
          sum = sum + difference*difference
        end
    end
    mse = sum /(width*height)
    println("The mean square error is $mse")
end
# Out:
# mserror (generic function with 1 method)

# %%
mserror(cat_oneg,firstres,rows,col)
# Out:
# The mean square error is 2.289494889326831

# %%
mserror(cat_twog,secondres,rows,col)
# Out:
# The mean square error is 10.512875584854278

# %%
X1
# Out:
# 167000×2 Array{Float64,2}:
#  3.611    -0.757514
#  3.61886  -0.772787
#  3.61886  -0.772787
#  3.61886  -0.772787
#  3.62673  -0.78806
#  3.62673  -0.78806
#  3.63459  -0.803334
#  3.63459  -0.803334
#  3.62673  -0.78806
#  3.62673  -0.78806
#  3.62673  -0.78806
#  3.61886  -0.772787
#  3.61886  -0.772787
#  ⋮
#  3.34192  -0.504662
#  3.3655   -0.550482
#  3.35764  -0.535208
#  3.33406  -0.489388
#  3.3655   -0.550482
#  3.24759  -0.321382
#  3.21615  -0.260289
#  3.35764  -0.535208
#  3.38908  -0.596301
#  3.40464  -0.65107
#  3.37336  -0.565755
#  3.31817  -0.483064

# %%
using Statistics 

maxiter = 200
nic = 2 
tol = 0.001
W = wei
X = Array(X1')
alpha = 1.0
retW = zeros(size(W))
wp = 0
wx= 0
#src : http://www.measurement.sk/2011/Patil.pdf pg 119 
      for i = 1:nic
            wp = W[i,:,]            
            #to-do create aux func
            if (i > 1)
                t = zeros(size(wp))
                for u = 1:(i-1)
                   k = sum(wp .* retW[u,:,])
                   t = t + k * retW[u,:,]
                end
                wp = wp - t 
            end
            normalize!(wp)
            iter = 0
            chg = 0
            converge = false
            while !converge && iter < maxiter
                iter+=1
                wx = wp' * X
                gdx,gddx = contrast_func(alpha,wx)
                xgdx = X .* gdx
                v1 = vec(mapslices(mean, xgdx, dims = 2))
                v2 = mean(gddx) * wp
                w1 = v1 - v2
                #to-do create aux func
                if (i > 1) 
                    t = zeros(size(w1))
                    for u = 1:(i-1)
                        k = sum(w1 .* retW[u,:,])
                        t = t + k * retW[u,:,]
                    end
                    w1 = w1 - t
                    println("wp=$wp")
                end
                normalize!(w1)
                #check for convergence
                chg =  abs.(abs.(sum(w1 .* wp)) .- 1.0)
                wp = w1
                converge = ( chg < tol )
            end
            retW[i,:,] = wp
            println(retW)
        end
# Out:
# [0.95562 -0.294602; 0.0 0.0]
# wp=[0.294602, 0.95562]
# [0.95562 -0.294602; -0.294602 -0.95562]

# %%
using LinearAlgebra
tanh.(alpha * a)
# Out:
# 2×2 Array{Float64,2}:
#  0.761594  0.964028
#  0.995055  0.999329
