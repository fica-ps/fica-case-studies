# %% [markdown]
# # Case study with mixed images using the FICA implementation

# %%
#using Pkg
#Pkg.add("ImageView")
using Images, FileIO, Colors

# %% [markdown]
# ## Loading the test images and converting them to a grayscale image
# For this case study we used 2 cat pictures, they will be refered to as cat one and cat two by
# order of appearance

# %%
cat_one = load("cat_one_resize.jpg")
cat_oneg = Gray.(cat_one)
# Out:
# 334×500 Array{Gray{N0f8},2} with eltype Gray{Normed{UInt8,8}}:
#  Gray{N0f8}(0.78)   Gray{N0f8}(0.78)   …  Gray{N0f8}(0.776)
#  Gray{N0f8}(0.784)  Gray{N0f8}(0.784)     Gray{N0f8}(0.776)
#  Gray{N0f8}(0.784)  Gray{N0f8}(0.784)     Gray{N0f8}(0.776)
#  Gray{N0f8}(0.784)  Gray{N0f8}(0.788)     Gray{N0f8}(0.78)
#  Gray{N0f8}(0.788)  Gray{N0f8}(0.788)     Gray{N0f8}(0.776)
#  Gray{N0f8}(0.788)  Gray{N0f8}(0.788)  …  Gray{N0f8}(0.773)
#  Gray{N0f8}(0.792)  Gray{N0f8}(0.792)     Gray{N0f8}(0.773)
#  Gray{N0f8}(0.792)  Gray{N0f8}(0.792)     Gray{N0f8}(0.769)
#  Gray{N0f8}(0.788)  Gray{N0f8}(0.788)     Gray{N0f8}(0.765)
#  Gray{N0f8}(0.788)  Gray{N0f8}(0.788)     Gray{N0f8}(0.765)
#  Gray{N0f8}(0.788)  Gray{N0f8}(0.788)  …  Gray{N0f8}(0.765)
#  Gray{N0f8}(0.784)  Gray{N0f8}(0.784)     Gray{N0f8}(0.757)
#  Gray{N0f8}(0.784)  Gray{N0f8}(0.784)     Gray{N0f8}(0.753)
#  ⋮                                     ⋱
#  Gray{N0f8}(0.82)   Gray{N0f8}(0.824)     Gray{N0f8}(0.69)
#  Gray{N0f8}(0.812)  Gray{N0f8}(0.82)      Gray{N0f8}(0.702)
#  Gray{N0f8}(0.808)  Gray{N0f8}(0.82)      Gray{N0f8}(0.698)
#  Gray{N0f8}(0.808)  Gray{N0f8}(0.82)   …  Gray{N0f8}(0.686)
#  Gray{N0f8}(0.804)  Gray{N0f8}(0.808)     Gray{N0f8}(0.702)
#  Gray{N0f8}(0.816)  Gray{N0f8}(0.8)       Gray{N0f8}(0.643)
#  Gray{N0f8}(0.796)  Gray{N0f8}(0.82)      Gray{N0f8}(0.627)
#  Gray{N0f8}(0.808)  Gray{N0f8}(0.804)     Gray{N0f8}(0.698)
#  Gray{N0f8}(0.82)   Gray{N0f8}(0.808)  …  Gray{N0f8}(0.714)
#  Gray{N0f8}(0.812)  Gray{N0f8}(0.816)     Gray{N0f8}(0.725)
#  Gray{N0f8}(0.804)  Gray{N0f8}(0.808)     Gray{N0f8}(0.706)
#  Gray{N0f8}(0.796)  Gray{N0f8}(0.804)     Gray{N0f8}(0.682)

# %%
cat_two = load("cat_two_resize.jpg")
cat_twog = Gray.(cat_two)
# Out:
# 334×500 Array{Gray{N0f8},2} with eltype Gray{Normed{UInt8,8}}:
#  Gray{N0f8}(1.0)    Gray{N0f8}(1.0)    …  Gray{N0f8}(0.529)
#  Gray{N0f8}(1.0)    Gray{N0f8}(1.0)       Gray{N0f8}(0.525)
#  Gray{N0f8}(1.0)    Gray{N0f8}(1.0)       Gray{N0f8}(0.51)
#  Gray{N0f8}(1.0)    Gray{N0f8}(1.0)       Gray{N0f8}(0.502)
#  Gray{N0f8}(1.0)    Gray{N0f8}(1.0)       Gray{N0f8}(0.498)
#  Gray{N0f8}(1.0)    Gray{N0f8}(1.0)    …  Gray{N0f8}(0.498)
#  Gray{N0f8}(1.0)    Gray{N0f8}(1.0)       Gray{N0f8}(0.49)
#  Gray{N0f8}(1.0)    Gray{N0f8}(1.0)       Gray{N0f8}(0.494)
#  Gray{N0f8}(1.0)    Gray{N0f8}(1.0)       Gray{N0f8}(0.49)
#  Gray{N0f8}(1.0)    Gray{N0f8}(1.0)       Gray{N0f8}(0.486)
#  Gray{N0f8}(1.0)    Gray{N0f8}(1.0)    …  Gray{N0f8}(0.482)
#  Gray{N0f8}(1.0)    Gray{N0f8}(1.0)       Gray{N0f8}(0.486)
#  Gray{N0f8}(1.0)    Gray{N0f8}(1.0)       Gray{N0f8}(0.486)
#  ⋮                                     ⋱
#  Gray{N0f8}(0.875)  Gray{N0f8}(0.886)     Gray{N0f8}(0.957)
#  Gray{N0f8}(0.89)   Gray{N0f8}(0.898)     Gray{N0f8}(0.957)
#  Gray{N0f8}(0.906)  Gray{N0f8}(0.914)     Gray{N0f8}(0.957)
#  Gray{N0f8}(0.922)  Gray{N0f8}(0.925)  …  Gray{N0f8}(0.957)
#  Gray{N0f8}(0.929)  Gray{N0f8}(0.933)     Gray{N0f8}(0.957)
#  Gray{N0f8}(0.937)  Gray{N0f8}(0.941)     Gray{N0f8}(0.957)
#  Gray{N0f8}(0.945)  Gray{N0f8}(0.945)     Gray{N0f8}(0.957)
#  Gray{N0f8}(0.953)  Gray{N0f8}(0.957)     Gray{N0f8}(0.957)
#  Gray{N0f8}(0.957)  Gray{N0f8}(0.957)  …  Gray{N0f8}(0.957)
#  Gray{N0f8}(0.957)  Gray{N0f8}(0.957)     Gray{N0f8}(0.953)
#  Gray{N0f8}(0.957)  Gray{N0f8}(0.957)     Gray{N0f8}(0.957)
#  Gray{N0f8}(0.957)  Gray{N0f8}(0.957)     Gray{N0f8}(0.953)

# %% [markdown]
# ## Mixing the images together to create 2 mixed images
# For each image we use a different factor ( array A )
# the first mixed image has a stronger presence from cat two and the second image a stronger presence from cat one

# %%
using LinearAlgebra
#convert image to array
mat_one = convert(Array{Float64},cat_oneg);
mat_two = convert(Array{Float64},cat_twog);
#get rows and column to later reconstruct the mixed image
rows,col = size(mat_one)
#convert 2D images to 1D (vector)
vec_one = vec(mat_one)';
vec_two = vec(mat_two)';

S = vcat(vec_one , vec_two)';

#generate first mixed signal
#factor used for the image
A = [0.2 , 0.8] 

X = (S .* A')'

X = X[1,:,]+X[2,:,]

imageX = reshape(X,rows,col)
save("mix_image_one.jpg",imageX)
load("mix_image_one.jpg")
# Out:
# 334×500 Array{Gray{N0f8},2} with eltype Gray{Normed{UInt8,8}}:
#  Gray{N0f8}(0.957)  Gray{N0f8}(0.957)  …  Gray{N0f8}(0.58)
#  Gray{N0f8}(0.957)  Gray{N0f8}(0.957)     Gray{N0f8}(0.58)
#  Gray{N0f8}(0.957)  Gray{N0f8}(0.957)     Gray{N0f8}(0.569)
#  Gray{N0f8}(0.957)  Gray{N0f8}(0.957)     Gray{N0f8}(0.557)
#  Gray{N0f8}(0.957)  Gray{N0f8}(0.957)     Gray{N0f8}(0.557)
#  Gray{N0f8}(0.957)  Gray{N0f8}(0.957)  …  Gray{N0f8}(0.553)
#  Gray{N0f8}(0.957)  Gray{N0f8}(0.957)     Gray{N0f8}(0.549)
#  Gray{N0f8}(0.957)  Gray{N0f8}(0.957)     Gray{N0f8}(0.549)
#  Gray{N0f8}(0.957)  Gray{N0f8}(0.957)     Gray{N0f8}(0.545)
#  Gray{N0f8}(0.957)  Gray{N0f8}(0.957)     Gray{N0f8}(0.541)
#  Gray{N0f8}(0.957)  Gray{N0f8}(0.957)  …  Gray{N0f8}(0.537)
#  Gray{N0f8}(0.957)  Gray{N0f8}(0.957)     Gray{N0f8}(0.537)
#  Gray{N0f8}(0.957)  Gray{N0f8}(0.957)     Gray{N0f8}(0.541)
#  ⋮                                     ⋱
#  Gray{N0f8}(0.867)  Gray{N0f8}(0.871)     Gray{N0f8}(0.906)
#  Gray{N0f8}(0.875)  Gray{N0f8}(0.878)     Gray{N0f8}(0.91)
#  Gray{N0f8}(0.89)   Gray{N0f8}(0.894)     Gray{N0f8}(0.902)
#  Gray{N0f8}(0.898)  Gray{N0f8}(0.902)  …  Gray{N0f8}(0.902)
#  Gray{N0f8}(0.906)  Gray{N0f8}(0.91)      Gray{N0f8}(0.902)
#  Gray{N0f8}(0.914)  Gray{N0f8}(0.918)     Gray{N0f8}(0.898)
#  Gray{N0f8}(0.918)  Gray{N0f8}(0.918)     Gray{N0f8}(0.894)
#  Gray{N0f8}(0.925)  Gray{N0f8}(0.922)     Gray{N0f8}(0.898)
#  Gray{N0f8}(0.929)  Gray{N0f8}(0.929)  …  Gray{N0f8}(0.906)
#  Gray{N0f8}(0.929)  Gray{N0f8}(0.929)     Gray{N0f8}(0.91)
#  Gray{N0f8}(0.925)  Gray{N0f8}(0.925)     Gray{N0f8}(0.906)
#  Gray{N0f8}(0.925)  Gray{N0f8}(0.922)     Gray{N0f8}(0.902)

# %%
#generate second mixed signal
#factor used for the image
A = [0.8 , 0.2] 

Z = (S .* A')'

Z = Z[1,:,]+Z[2,:,]

imageZ = reshape(Z,rows,col)
save("mix_image_two.jpg",imageZ)
load("mix_image_two.jpg")
# Out:
# 334×500 Array{Gray{N0f8},2} with eltype Gray{Normed{UInt8,8}}:
#  Gray{N0f8}(0.824)  Gray{N0f8}(0.824)  …  Gray{N0f8}(0.725)
#  Gray{N0f8}(0.827)  Gray{N0f8}(0.824)     Gray{N0f8}(0.725)
#  Gray{N0f8}(0.827)  Gray{N0f8}(0.827)     Gray{N0f8}(0.725)
#  Gray{N0f8}(0.831)  Gray{N0f8}(0.831)     Gray{N0f8}(0.722)
#  Gray{N0f8}(0.835)  Gray{N0f8}(0.831)     Gray{N0f8}(0.722)
#  Gray{N0f8}(0.835)  Gray{N0f8}(0.835)  …  Gray{N0f8}(0.722)
#  Gray{N0f8}(0.835)  Gray{N0f8}(0.835)     Gray{N0f8}(0.718)
#  Gray{N0f8}(0.835)  Gray{N0f8}(0.835)     Gray{N0f8}(0.718)
#  Gray{N0f8}(0.831)  Gray{N0f8}(0.831)     Gray{N0f8}(0.71)
#  Gray{N0f8}(0.831)  Gray{N0f8}(0.831)     Gray{N0f8}(0.71)
#  Gray{N0f8}(0.831)  Gray{N0f8}(0.831)  …  Gray{N0f8}(0.71)
#  Gray{N0f8}(0.827)  Gray{N0f8}(0.827)     Gray{N0f8}(0.706)
#  Gray{N0f8}(0.827)  Gray{N0f8}(0.827)     Gray{N0f8}(0.702)
#  ⋮                                     ⋱
#  Gray{N0f8}(0.835)  Gray{N0f8}(0.831)     Gray{N0f8}(0.741)
#  Gray{N0f8}(0.827)  Gray{N0f8}(0.831)     Gray{N0f8}(0.753)
#  Gray{N0f8}(0.827)  Gray{N0f8}(0.835)     Gray{N0f8}(0.749)
#  Gray{N0f8}(0.827)  Gray{N0f8}(0.835)  …  Gray{N0f8}(0.745)
#  Gray{N0f8}(0.827)  Gray{N0f8}(0.831)     Gray{N0f8}(0.749)
#  Gray{N0f8}(0.835)  Gray{N0f8}(0.835)     Gray{N0f8}(0.714)
#  Gray{N0f8}(0.831)  Gray{N0f8}(0.835)     Gray{N0f8}(0.698)
#  Gray{N0f8}(0.835)  Gray{N0f8}(0.839)     Gray{N0f8}(0.737)
#  Gray{N0f8}(0.835)  Gray{N0f8}(0.843)  …  Gray{N0f8}(0.761)
#  Gray{N0f8}(0.839)  Gray{N0f8}(0.843)     Gray{N0f8}(0.776)
#  Gray{N0f8}(0.835)  Gray{N0f8}(0.839)     Gray{N0f8}(0.761)
#  Gray{N0f8}(0.831)  Gray{N0f8}(0.835)     Gray{N0f8}(0.745)

# %% [markdown]
# ## Applying the FICA algorithm

# %%
include("fastICA.jl")
mixed_signal = hcat(X,Z);  
X1 = fastICA.whiten(mixed_signal)
X2 =  X1 * mixed_signal' 
J = fastICA.fast_ica(100,2,Array(X2'),0.000001,1.,true)
# Out:
# wp = [0.835952, 0.164048]
# w1 = [-0.981284, -0.192568]
# W for iter 1 = [0.835952 0.164048; 0.377426 0.634286]
# Change for iter 1 = 0.14810359508933124
# wp = [-0.981284, -0.192568]
# w1 = [0.981284, 0.192568]
# W for iter 2 = [0.835952 0.164048; 0.377426 0.634286]
# Change for iter 2 = 1.1102230246251565e-16
# wp = [-0.778824, 0.400897]
# w1 = [0.576916, -0.816804]
# W for iter 1 = [0.835952 0.164048; 0.373057 0.626943]
# Change for iter 1 = 0.22322994181239042
# WARNING: replacing module fastICA.
# wp = [0.576916, -0.816804]
# w1 = [-0.745608, 0.666384]
# W for iter 2 = [0.835952 0.164048; 0.373057 0.626943]
# Change for iter 2 = 0.025541527630372318
# wp = [-0.745608, 0.666384]
# w1 = [0.691118, -0.722742]
# W for iter 3 = [0.835952 0.164048; 0.373057 0.626943]
# Change for iter 3 = 0.003072654029270261
# wp = [0.691118, -0.722742]
# w1 = [-0.712938, 0.701227]
# W for iter 4 = [0.835952 0.164048; 0.373057 0.626943]
# Change for iter 4 = 0.0004694963754464654
# wp = [-0.712938, 0.701227]
# w1 = [0.704873, -0.709333]
# W for iter 5 = [0.835952 0.164048; 0.373057 0.626943]
# Change for iter 5 = 6.538186553262104e-5
# wp = [0.704873, -0.709333]
# w1 = [-0.707947, 0.706266]
# W for iter 6 = [0.835952 0.164048; 0.373057 0.626943]
# Change for iter 6 = 9.42854117180758e-6
# wp = [-0.707947, 0.706266]
# w1 = [0.706789, -0.707425]
# W for iter 7 = [0.835952 0.164048; 0.373057 0.626943]
# Change for iter 7 = 1.3418008431020922e-6
# wp = [0.706789, -0.707425]
# w1 = [-0.707227, 0.706987]
# W for iter 8 = [0.835952 0.164048; 0.373057 0.626943]
# Change for iter 8 = 1.9191132527573984e-7
# 2×2 Array{Float64,2}:
#   0.981284  0.192568
#  -0.707227  0.706987

# %% [markdown]
# ## Results

# %%
W = J * mixed_signal'
save("res_one.jpg",map(clamp01nan, reshape((W[1,:,]-W[2,:,]),rows,col)))
load("res_one.jpg")
# Out:
# 334×500 Array{Gray{N0f8},2} with eltype Gray{Normed{UInt8,8}}:
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  …  Gray{N0f8}(0.604)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.6)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.584)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.573)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.569)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  …  Gray{N0f8}(0.565)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.557)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.557)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.557)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.549)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  …  Gray{N0f8}(0.545)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.545)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.549)
#  ⋮                                                  ⋱
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  …  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  …  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)

# %%
save("res_two.jpg",map(clamp01nan, reshape((W[1,:,]+W[2,:,]),rows,col)))
load("res_two.jpg")
# Out:
# 334×500 Array{Gray{N0f8},2} with eltype Gray{Normed{UInt8,8}}:
#  Gray{N0f8}(1.0)    Gray{N0f8}(1.0)    …  Gray{N0f8}(0.812)
#  Gray{N0f8}(1.0)    Gray{N0f8}(1.0)       Gray{N0f8}(0.808)
#  Gray{N0f8}(1.0)    Gray{N0f8}(1.0)       Gray{N0f8}(0.804)
#  Gray{N0f8}(1.0)    Gray{N0f8}(1.0)       Gray{N0f8}(0.804)
#  Gray{N0f8}(1.0)    Gray{N0f8}(1.0)       Gray{N0f8}(0.8)
#  Gray{N0f8}(1.0)    Gray{N0f8}(1.0)    …  Gray{N0f8}(0.8)
#  Gray{N0f8}(1.0)    Gray{N0f8}(1.0)       Gray{N0f8}(0.796)
#  Gray{N0f8}(1.0)    Gray{N0f8}(1.0)       Gray{N0f8}(0.792)
#  Gray{N0f8}(1.0)    Gray{N0f8}(1.0)       Gray{N0f8}(0.788)
#  Gray{N0f8}(1.0)    Gray{N0f8}(1.0)       Gray{N0f8}(0.784)
#  Gray{N0f8}(1.0)    Gray{N0f8}(1.0)    …  Gray{N0f8}(0.784)
#  Gray{N0f8}(1.0)    Gray{N0f8}(1.0)       Gray{N0f8}(0.78)
#  Gray{N0f8}(1.0)    Gray{N0f8}(1.0)       Gray{N0f8}(0.78)
#  ⋮                                     ⋱
#  Gray{N0f8}(0.984)  Gray{N0f8}(0.984)     Gray{N0f8}(0.914)
#  Gray{N0f8}(0.988)  Gray{N0f8}(0.992)     Gray{N0f8}(0.925)
#  Gray{N0f8}(0.992)  Gray{N0f8}(0.996)     Gray{N0f8}(0.922)
#  Gray{N0f8}(0.992)  Gray{N0f8}(0.996)  …  Gray{N0f8}(0.918)
#  Gray{N0f8}(0.996)  Gray{N0f8}(1.0)       Gray{N0f8}(0.918)
#  Gray{N0f8}(1.0)    Gray{N0f8}(1.0)       Gray{N0f8}(0.886)
#  Gray{N0f8}(0.996)  Gray{N0f8}(0.996)     Gray{N0f8}(0.871)
#  Gray{N0f8}(0.996)  Gray{N0f8}(1.0)       Gray{N0f8}(0.914)
#  Gray{N0f8}(1.0)    Gray{N0f8}(1.0)    …  Gray{N0f8}(0.933)
#  Gray{N0f8}(1.0)    Gray{N0f8}(1.0)       Gray{N0f8}(0.945)
#  Gray{N0f8}(1.0)    Gray{N0f8}(0.996)     Gray{N0f8}(0.933)
#  Gray{N0f8}(1.0)    Gray{N0f8}(0.996)     Gray{N0f8}(0.918)
