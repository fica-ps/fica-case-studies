# %% [markdown]
# # Case Study with mixed signals
# ## This case study attempts to separate two mixed signals into their original form

# %%
#using Pkg
#Pkg.add("Plots")
using Plots

s1 = sin.((1:1000)./20)
plot(s1, linewidth=2, title = "S1")

# %%
s2 = vec(repeat(((1:200).-100)/100, 5))
plot(s2,linewidth=2,title="S2")

# %% [markdown]
# ## Mixing the previous functions twice using different factors so we have enough data to apply the algorithm

# %%
#mixing matrix
A = [0.291 -0.5439 ; 0.6557 0.5572]
S = hcat(s1,s2)
X = S * A
# Out:
# 1000×2 Array{Float64,2}:
#  -0.634599  -0.578812
#  -0.613534  -0.600355
#  -0.592543  -0.621763
#  -0.571659  -0.642968
#  -0.55092   -0.663903
#  -0.530362  -0.684501
#  -0.510018  -0.704698
#  -0.489923  -0.724429
#  -0.470112  -0.74363
#  -0.450617  -0.76224
#  -0.431471  -0.780198
#  -0.412705  -0.797445
#  -0.39435   -0.813925
#   ⋮
#   0.371709   0.891898
#   0.3885     0.87834
#   0.405796   0.86384
#   0.423569   0.848449
#   0.441791   0.832218
#   0.460433   0.815202
#   0.479465   0.797458
#   0.498855   0.779044
#   0.518572   0.760019
#   0.538583   0.740446
#   0.558853   0.720387
#   0.579349   0.699906

# %%
plot(X[:,1], linewidth=2, title = "X1")

# %%
plot(X[:,2], linewidth=2, title = "X2")

# %% [markdown]
# ## Data whitening, application of the FICA algorithm

# %%
include("fastICA.jl")
X1 = fastICA.whiten(X,false)
J = fastICA.fast_ica(200,2,Array(X1'),0.0001,1.,false)
W = J * X'
# Out:
# wp = [0.375881, 0.624119]
# w1 = [-0.516469, -0.856306]
# W for iter 1 = [0.375881 0.624119; 0.979178 0.624774]
# Change for iter 1 = 0.2714323321478952
# wp = [-0.516469, -0.856306]
# w1 = [0.51702, 0.855973]
# W for iter 2 = [0.375881 0.624119; 0.979178 0.624774]
# Change for iter 2 = 2.0708477521669266e-7
# wp = [-0.0993864, -0.785724]
# w1 = [-0.901386, -0.433016]
# W for iter 1 = [0.375881 0.624119; 0.610479 0.389521]
# Change for iter 1 = 0.5701833070172759
# wp = [-0.901386, -0.433016]
# w1 = [-0.0394839, -0.99922]
# W for iter 2 = [0.375881 0.624119; 0.610479 0.389521]
# Change for iter 2 = 0.5317314040282897
# wp = [-0.0394839, -0.99922]
# w1 = [-0.953432, -0.301608]
# W for iter 3 = [0.375881 0.624119; 0.610479 0.389521]
# Change for iter 3 = 0.660981562501751
# wp = [-0.953432, -0.301608]
# w1 = [0.0539727, -0.998542]
# W for iter 4 = [0.375881 0.624119; 0.610479 0.389521]
# Change for iter 4 = 0.7502904608650497
# wp = [0.0539727, -0.998542]
# w1 = [-0.98855, -0.150895]
# W for iter 5 = [0.375881 0.624119; 0.610479 0.389521]
# Change for iter 5 = 0.9026793205754374
# wp = [-0.98855, -0.150895]
# w1 = [0.150127, -0.988667]
# W for iter 6 = [0.375881 0.624119; 0.610479 0.389521]
# Change for iter 6 = 0.9992227512232459
# wp = [0.150127, -0.988667]
# w1 = [-0.999983, 0.00581272]
# W for iter 7 = [0.375881 0.624119; 0.610479 0.389521]
# Change for iter 7 = 0.8441287800491506
# wp = [-0.999983, 0.00581272]
# w1 = [0.243479, -0.969906]
# W for iter 8 = [0.375881 0.624119; 0.610479 0.389521]
# Change for iter 8 = 0.7508876169765424
# wp = [0.243479, -0.969906]
# w1 = [-0.988237, 0.152927]
# W for iter 9 = [0.375881 0.624119; 0.610479 0.389521]
# Change for iter 9 = 0.611059934526896
# wp = [-0.988237, 0.152927]
# w1 = [0.329174, -0.944269]
# W for iter 10 = [0.375881 0.624119; 0.610479 0.389521]
# Change for iter 10 = 0.5302928519630468
# wp = [0.329174, -0.944269]
# w1 = [-0.960195, 0.279332]
# W for iter 11 = [0.375881 0.624119; 0.610479 0.389521]
# Change for iter 11 = 0.4201641066739006
# wp = [-0.960195, 0.279332]
# w1 = [0.404073, -0.914727]
# W for iter 12 = [0.375881 0.624119; 0.610479 0.389521]
# Change for iter 12 = 0.35649937975939106
# wp = [0.404073, -0.914727]
# w1 = [-0.924509, 0.381161]
# W for iter 13 = [0.375881 0.624119; 0.610479 0.389521]
# Change for iter 13 = 0.27777286611799645
# wp = [-0.924509, 0.381161]
# w1 = [0.467007, -0.884254]
# W for iter 14 = [0.375881 0.624119; 0.610479 0.389521]
# Change for iter 14 = 0.23120499899695546
# wp = [0.467007, -0.884254]
# w1 = [-0.887922, 0.459994]
# W for iter 15 = [0.375881 0.624119; 0.610479 0.389521]
# Change for iter 15 = 0.17858306810233593
# wp = [-0.887922, 0.459994]
# w1 = [0.51837, -0.855157]
# W for iter 16 = [0.375881 0.624119; 0.610479 0.389521]
# Change for iter 16 = 0.1463611681320256
# wp = [0.51837, -0.855157]
# w1 = [-0.854299, 0.519782]
# W for iter 17 = [0.375881 0.624119; 0.610479 0.389521]
# Change for iter 17 = 0.11266246287424009
# wp = [-0.854299, 0.519782]
# w1 = [0.559457, -0.82886]
# W for iter 18 = [0.375881 0.624119; 0.610479 0.389521]
# Change for iter 18 = 0.0912305540806273
# wp = [0.559457, -0.82886]
# w1 = [-0.825252, 0.564765]
# W for iter 19 = [0.375881 0.624119; 0.610479 0.389521]
# Change for iter 19 = 0.0701962961087994
# wp = [-0.825252, 0.564765]
# w1 = [0.591901, -0.806011]
# W for iter 20 = [0.375881 0.624119; 0.610479 0.389521]
# Change for iter 20 = 0.056325892179088566
# wp = [0.591901, -0.806011]
# w1 = [-0.801059, 0.598585]
# W for iter 21 = [0.375881 0.624119; 0.610479 0.389521]
# Change for iter 21 = 0.043386289142006484
# wp = [-0.801059, 0.598585]
# w1 = [0.617321, -0.786712]
# W for iter 22 = [0.375881 0.624119; 0.610479 0.389521]
# Change for iter 22 = 0.03457575055380491
# wp = [0.617321, -0.786712]
# w1 = [-0.781357, 0.624085]
# W for iter 23 = [0.375881 0.624119; 0.610479 0.389521]
# Change for iter 23 = 0.026677699006318667
# wp = [-0.781357, 0.624085]
# w1 = [0.637149, -0.77074]
# W for iter 24 = [0.375881 0.624119; 0.610479 0.389521]
# Change for iter 24 = 0.021151830165306196
# wp = [0.637149, -0.77074]
# w1 = [-0.765534, 0.643395]
# W for iter 25 = [0.375881 0.624119; 0.610479 0.389521]
# Change for iter 25 = 0.016349741040031285
# wp = [-0.765534, 0.643395]
# w1 = [0.652583, -0.757717]
# W for iter 26 = [0.375881 0.624119; 0.610479 0.389521]
# Change for iter 26 = 0.012913811441656264
# wp = [0.652583, -0.757717]
# w1 = [-0.752942, 0.658087]
# W for iter 27 = [0.375881 0.624119; 0.610479 0.389521]
# Change for iter 27 = 0.009998997342189009
# wp = [-0.752942, 0.658087]
# w1 = [0.664584, -0.747213]
# W for iter 28 = [0.375881 0.624119; 0.610479 0.389521]
# Change for iter 28 = 0.007875185093845216
# wp = [0.664584, -0.747213]
# w1 = [-0.742978, 0.669316]
# W for iter 29 = [0.375881 0.624119; 0.610479 0.389521]
# Change for iter 29 = 0.006106790980070054
# wp = [-0.742978, 0.669316]
# w1 = [0.673916, -0.738808]
# W for iter 30 = [0.375881 0.624119; 0.610479 0.389521]
# Change for iter 30 = 0.0047993877007854735
# wp = [0.673916, -0.738808]
# w1 = [-0.735126, 0.67793]
# W for iter 31 = [0.375881 0.624119; 0.610479 0.389521]
# Change for iter 31 = 0.0037263939994828243
# wp = [-0.735126, 0.67793]
# w1 = [0.681173, -0.732123]
# W for iter 32 = [0.375881 0.624119; 0.610479 0.389521]
# Change for iter 32 = 0.0029238679935561507
# wp = [0.681173, -0.732123]
# w1 = [-0.728955, 0.684562]
# W for iter 33 = [0.375881 0.624119; 0.610479 0.389521]
# Change for iter 33 = 0.0022725629420727866
# wp = [-0.728955, 0.684562]
# w1 = [0.686819, -0.726828]
# W for iter 34 = [0.375881 0.624119; 0.610479 0.389521]
# Change for iter 34 = 0.0017809449929219179
# wp = [0.686819, -0.726828]
# w1 = [-0.724114, 0.689681]
# W for iter 35 = [0.375881 0.624119; 0.610479 0.389521]
# Change for iter 35 = 0.0013854123251229034
# wp = [-0.724114, 0.689681]
# w1 = [0.691214, -0.72265]
# W for iter 36 = [0.375881 0.624119; 0.610479 0.389521]
# Change for iter 36 = 0.0010846907865608157
# wp = [0.691214, -0.72265]
# w1 = [-0.720321, 0.693641]
# W for iter 37 = [0.375881 0.624119; 0.610479 0.389521]
# Change for iter 37 = 0.0008443695380617733
# wp = [-0.720321, 0.693641]
# w1 = [0.694636, -0.719361]
# W for iter 38 = [0.375881 0.624119; 0.610479 0.389521]
# Change for iter 38 = 0.0006606130793893605
# wp = [0.694636, -0.719361]
# w1 = [-0.717352, 0.696711]
# W for iter 39 = [0.375881 0.624119; 0.610479 0.389521]
# Change for iter 39 = 0.0005145312815706404
# wp = [-0.717352, 0.696711]
# w1 = [0.697302, -0.716777]
# W for iter 40 = [0.375881 0.624119; 0.610479 0.389521]
# Change for iter 40 = 0.00040233361742259
# wp = [0.697302, -0.716777]
# w1 = [-0.71503, 0.699094]
# W for iter 41 = [0.375881 0.624119; 0.610479 0.389521]
# Change for iter 41 = 0.0003135017180233568
# wp = [-0.71503, 0.699094]
# w1 = [0.69938, -0.71475]
# W for iter 42 = [0.375881 0.624119; 0.610479 0.389521]
# Change for iter 42 = 0.00024503569972822437
# wp = [0.69938, -0.71475]
# w1 = [-0.713215, 0.700945]
# W for iter 43 = [0.375881 0.624119; 0.610479 0.389521]
# Change for iter 43 = 0.00019099957796964162
# wp = [-0.713215, 0.700945]
# w1 = [0.700999, -0.713162]
# W for iter 44 = [0.375881 0.624119; 0.610479 0.389521]
# Change for iter 44 = 0.00014923777892195123
# wp = [0.700999, -0.713162]
# w1 = [-0.711797, 0.702385]
# W for iter 45 = [0.375881 0.624119; 0.610479 0.389521]
# Change for iter 45 = 0.00011635890609951183
# wp = [-0.711797, 0.702385]
# w1 = [0.702262, -0.711919]
# W for iter 46 = [0.375881 0.624119; 0.610479 0.389521]
# Change for iter 46 = 9.089399646922125e-5
# WARNING: replacing module fastICA.
# 2×1000 Array{Float64,2}:
#  -0.823548   -0.831098    -0.838569   …   0.91226    0.90557    0.898636
#  -0.0335881  -0.00345788   0.0265247     -0.148911  -0.120395  -0.091421

# %% [markdown]
# ## Plotting of results

# %%
plot(W[1,:,],linewidth=2, title = "S'1")

# %%
plot(W[2,:,],linewidth=2, title = "S'2")
